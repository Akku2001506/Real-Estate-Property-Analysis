# %% [markdown]
# #Real Estate Property Analysis

# %% [markdown]
# #Task 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
from io import StringIO
df = pd.read_csv(StringIO(data))

# Group by city and calculate the average price
city_avg_price = df.groupby('City')['Price (Lakhs)'].mean().sort_values()

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
city_avg_price.plot(kind='barh', color='skyblue')
plt.title('Average Property Price by City')
plt.xlabel('Average Price (Lakhs)')
plt.ylabel('City')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from io import StringIO

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Calculate the average price for each property type
avg_price_by_type = df.groupby('Property Type')['Price (Lakhs)'].mean().sort_values()

# Create a stacked bar chart
plt.figure(figsize=(10, 6))
avg_price_by_type.plot(kind='bar', color='lightcoral')
plt.title('Average Price by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Average Price (Lakhs)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 3

# %%
import pandas as pd
from io import StringIO

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Find the top 3 most expensive properties
top_3_expensive = df.nlargest(3, 'Price (Lakhs)')

# Display the top 3 properties
print("Top 3 Most Expensive Properties:")
print(top_3_expensive.to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# Top 3 Most Expensive Properties:
# | Property ID   | City       | Property Type   | BHK   | Price (Lakhs)   | Area (Sq. Ft)   | Seller Type   | Status    |
# |:--------------|:-----------|:----------------|:------|:----------------|:----------------|:--------------|:----------|
# | 121           | Mumbai     | Villa           | 5BHK  | 280             | 3300            | Builder       | Sold      |
# | 110           | Chandigarh | Villa           | 5BHK  | 275             | 3200            | Owner         | Available |
# | 102           | Delhi      | Villa           | 4BHK  | 250             | 2500            | Owner         | Sold      |

# %% [markdown]
# #Task 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Calculate the value counts of each status
status_counts = df['Status'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightgreen', 'lightcoral'])
plt.title('Percentage of Properties by Status')
plt.ylabel('Status')  # Adding ylabel for clarity
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Calculate Price per Sq. Ft
df['Price Per Sq. Ft'] = df['Price (Lakhs)'] * 100000 / df['Area (Sq. Ft)']  # 1 Lakh = 100,000

# Calculate Average Price per Sq. Ft by City
avg_price_per_sqft_by_city = df.groupby('City')['Price Per Sq. Ft'].mean().sort_values()

# Create a bar chart
plt.figure(figsize=(12, 6))
avg_price_per_sqft_by_city.plot(kind='bar', color='skyblue')
plt.title('Average Price Per Sq. Ft by City')
plt.xlabel('City')
plt.ylabel('Average Price (INR) Per Sq. Ft')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Task 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Load the dataset from the provided string
data = """
Property ID,City,Property Type,BHK,Price (Lakhs),Area (Sq. Ft),Seller Type,Status
101,Mumbai,Apartment,2BHK,95,850,Builder,Available
102,Delhi,Villa,4BHK,250,2500,Owner,Sold
103,Bangalore,Apartment,3BHK,125,1200,Agent,Available
104,Hyderabad,Independent Hou,5BHK,180,3000,Owner,Under Construction
105,Chennai,Apartment,1BHK,45,600,Builder,Available
106,Pune,Villa,3BHK,170,2000,Agent,Sold
107,Kolkata,Apartment,2BHK,85,900,Owner,Available
108,Ahmedabad,Independent Hou,4BHK,140,2400,Builder,Available
109,Jaipur,Apartment,3BHK,110,1150,Agent,Sold
110,Chandigarh,Villa,5BHK,275,3200,Owner,Available
111,Mumbai,Apartment,1BHK,60,500,Builder,Under Construction
112,Delhi,Independent Hou,3BHK,130,1800,Agent,Available
113,Bangalore,Apartment,2BHK,90,850,Owner,Sold
114,Hyderabad,Villa,4BHK,230,2800,Builder,Available
115,Chennai,Apartment,3BHK,105,1100,Agent,Available
116,Pune,Independent Hou,5BHK,185,3100,Owner,Sold
117,Kolkata,Villa,3BHK,165,1900,Agent,Available
118,Ahmedabad,Apartment,2BHK,75,800,Builder,Available
119,Jaipur,Apartment,1BHK,50,550,Agent,Sold
120,Chandigarh,Independent Hou,4BHK,150,2500,Owner,Available
121,Mumbai,Villa,5BHK,280,3300,Builder,Sold
122,Delhi,Apartment,3BHK,115,1200,Agent,Available
123,Bangalore,Apartment,2BHK,92,900,Owner,Available
124,Hyderabad,Independent Hou,4BHK,145,2200,Agent,Available
125,Chennai,Villa,3BHK,175,2100,Builder,Sold
"""

# Create a Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Define price ranges
bins = [0, 100, 200, 300]  # Adjust bins as needed
labels = ['Low', 'Medium', 'High']
df['Price Range'] = pd.cut(df['Price (Lakhs)'], bins=bins, right=False, labels=labels)

# Analyze the count of properties in each price range
price_range_counts = df['Price Range'].value_counts().sort_index()

# Create a bar chart
plt.figure(figsize=(8, 6))
price_range_counts.plot(kind='bar', color='lightgreen')
plt.title('Distribution of Properties Across Price Ranges')
plt.xlabel('Price Range')
plt.ylabel('Number of Properties')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Sorry for late submit
